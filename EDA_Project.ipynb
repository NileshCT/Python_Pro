# %% [markdown]
# <a href="https://colab.research.google.com/github/NileshCT/Hello-Nilesh/blob/main/EDA_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Importing required labraries**

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split, KFold
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
from sklearn.metrics import accuracy_score, classification_report
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **Importing input dataset required for eda**

# %%
data=pd.read_csv("/content/drive/MyDrive/dataset.csv")

# %%
data.head(50)
# Out:
#                                    permalink  \
# 0                        /organization/-fame
# 1                     /organization/-qounter
# 2        /organization/-the-one-of-them-inc-
# 3                      /organization/0-6-com
# 4             /organization/004-technologies
# 5           /organization/01games-technology
# 6        /organization/0ndine-biomedical-inc
# 7                       /organization/0xdata
# 8                            /organization/1
# 9                  /organization/1-2-3-listo
# 10                     /organization/1-4-all
# 11            /organization/1-618-technology
# 12               /organization/1-800-dentist
# 13               /organization/1-800-doctors
# 14  /organization/1-800-publicrelations-inc-
# 15                /organization/1-mainstream
# 16                     /organization/1-of-99
# 17                 /organization/10-20-media
# 18             /organization/10-minutes-with
# 19                  /organization/1000-corks
# ...

# %%
data.tail()
# Out:
#                                                permalink  \
# 66363  /organization/zznode-science-and-technology-co...
# 66364                          /organization/zzzzapp-com
# 66365                                /organization/Áeron
# 66366                              /organization/Ôasys-2
# 66367  /organization/İnovatiff-reklam-ve-tanıtım-hizm...
#
#                                              name            homepage_url  \
# 66363               ZZNode Science and Technology   http://www.zznode.com
# 66364                       Zzzzapp Wireless ltd.  http://www.zzzzapp.com
# 66365                                       ÁERON    http://www.aeron.hu/
# 66366                                       Ôasys    http://www.oasys.io/
# 66367  İnovatiff Reklam ve Tanıtım Hizmetleri Tic    http://inovatiff.com
#
#                                            category_list funding_total_usd  \
# 66363                                Enterprise Software           1587301
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66368 entries, 0 to 66367
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   permalink          66368 non-null  object
#  1   name               66367 non-null  object
#  2   homepage_url       61310 non-null  object
#  3   category_list      63220 non-null  object
#  4   funding_total_usd  66368 non-null  object
#  5   status             66368 non-null  object
#  6   country_code       59410 non-null  object
#  7   state_code         57821 non-null  object
#  8   region             58338 non-null  object
#  9   city               58340 non-null  object
#  10  funding_rounds     66368 non-null  int64
#  11  founded_at         51147 non-null  object
#  12  first_funding_at   66344 non-null  object
#  13  last_funding_at    66368 non-null  object
# dtypes: int64(1), object(13)
# memory usage: 7.1+ MB

# %%
data.shape
# Out:
# (66368, 14)

# %%
data.nunique()
# Out:
# permalink            66368
# name                 66102
# homepage_url         61191
# category_list        27296
# funding_total_usd    18896
# status                   4
# country_code           137
# state_code             311
# region                1092
# city                  5111
# funding_rounds          19
# founded_at            3978
# first_funding_at      4817
# last_funding_at       4518
# dtype: int64

# %%
data.describe()
# Out:
#        funding_rounds
# count    66368.000000
# mean         1.732522
# std          1.360251
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max         19.000000

# %% [markdown]
# # **Created clone file.**

# %%
data2=data.copy()

# %%
#drop unwanted data
data2.drop(["last_funding_at","first_funding_at","founded_at","funding_rounds","state_code","funding_total_usd","name","homepage_url"],axis=1)
# Out:
#                                                permalink  \
# 0                                    /organization/-fame
# 1                                 /organization/-qounter
# 2                    /organization/-the-one-of-them-inc-
# 3                                  /organization/0-6-com
# 4                         /organization/004-technologies
# ...                                                  ...
# 66363  /organization/zznode-science-and-technology-co...
# 66364                          /organization/zzzzapp-com
# 66365                                /organization/Áeron
# 66366                              /organization/Ôasys-2
# 66367  /organization/İnovatiff-reklam-ve-tanıtım-hizm...
#
#                                            category_list     status  \
# 0                                                  Media  operating
# 1      Application Platforms|Real Time|Social Network...  operating
# 2                                      Apps|Games|Mobile  operating
# ...

# %% [markdown]
# # **Funtion to remove punctuation**

# %%
#Funtion to remove punctuation
def remove_punctuation(text):
    '''a function for removing punctuation'''
    import string
    # replacing the punctuations with no space, 
    # which in effect deletes the punctuation marks 
    translator = str.maketrans('', '', string.punctuation)
    # return the text stripped of punctuation marks
    return text.translate(translator)

# %%
data2["status"]= data2["status"].apply(remove_punctuation)

# %%
data2["permalink"]= data2["permalink"].apply(remove_punctuation)

# %% [markdown]
# ## **Removeing Stop Words From Data**

# %%
#Removeing Stop Words From Data
import nltk
nltk.download('stopwords')
stopwords = nltk.corpus.stopwords.words("english")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
sw = stopwords[:]

# %%
print("Number of stopwords: ", len(sw))
# Out:
# Number of stopwords:  179

# %%
def stopwords(text):
    '''a function for removing the stopword'''
    # removing the stop words and lowercasing the selected words
    text = [word.lower() for word in text.split() if word.lower() not in sw]
    # joining the list of words with space separator
    return " ".join(text)

# %%
data['status'] = data['status'].apply(stopwords)
data.head(10)
# Out:
#                              permalink                    name  \
# 0                  /organization/-fame                   #fame
# 1               /organization/-qounter                :Qounter
# 2  /organization/-the-one-of-them-inc-  (THE) ONE of THEM,Inc.
# 3                /organization/0-6-com                 0-6.com
# 4       /organization/004-technologies        004 Technologies
# 5     /organization/01games-technology      01Games Technology
# 6  /organization/0ndine-biomedical-inc  Ondine Biomedical Inc.
# 7                 /organization/0xdata                  H2O.ai
# 8                      /organization/1                One Inc.
# 9            /organization/1-2-3-listo             1,2,3 Listo
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
# 5             http://www.01games.hk/
# ...

# %%
data['permalink'] = data['permalink'].apply(stopwords)
data.head(10)
# Out:
#                              permalink                    name  \
# 0                  /organization/-fame                   #fame
# 1               /organization/-qounter                :Qounter
# 2  /organization/-the-one-of-them-inc-  (THE) ONE of THEM,Inc.
# 3                /organization/0-6-com                 0-6.com
# 4       /organization/004-technologies        004 Technologies
# 5     /organization/01games-technology      01Games Technology
# 6  /organization/0ndine-biomedical-inc  Ondine Biomedical Inc.
# 7                 /organization/0xdata                  H2O.ai
# 8                      /organization/1                One Inc.
# 9            /organization/1-2-3-listo             1,2,3 Listo
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
# 5             http://www.01games.hk/
# ...

# %% [markdown]
# ## **Collect vocabulary count**

# %%
#Collect vocabulary count
# create a count vectorizer object
count_vectorizer = CountVectorizer()
# fit the count vectorizer using the text data
count_vectorizer.fit(data['status'])
# collect the vocabulary items used in the vectorizer
dictionary = count_vectorizer.vocabulary_.items()

# %% [markdown]
# # **lists to store the vocab and counts**

# %%
# lists to store the vocab and counts
vocab = []
count = []
# iterate through each vocab and count append the value to designated lists
for key, value in dictionary:
    vocab.append(key)
    count.append(value)
# store the count in panadas dataframe with vocab as index
vocab_bef_stem = pd.Series(count, index=vocab)
# sort the dataframe
vocab_bef_stem = vocab_bef_stem.sort_values(ascending=False)

# %%
top_vacab = vocab_bef_stem.head(20)
top_vacab.plot(kind = 'bar', figsize=(10,5))

# %% [markdown]
# # **Collect vocabulary count**

# %%
#Collect vocabulary count
# create a count vectorizer object
count_vectorizer = CountVectorizer()
# fit the count vectorizer using the text data
count_vectorizer.fit(data['permalink'])
# collect the vocabulary items used in the vectorizer
dictionary = count_vectorizer.vocabulary_.items()

# %% [markdown]
# # ** lists to store the vocab and counts**

# %%
# lists to store the vocab and counts
vocab = []
count = []
# iterate through each vocab and count append the value to designated lists
for key, value in dictionary:
    vocab.append(key)
    count.append(value)
# store the count in panadas dataframe with vocab as index
vocab_bef_stem = pd.Series(count, index=vocab)
# sort the dataframe
vocab_bef_stem = vocab_bef_stem.sort_values(ascending=False)

# %%
top_vacab = vocab_bef_stem.head(20)
top_vacab.plot(kind = 'bar', figsize=(10,5))

# %% [markdown]
# ## **Stemming function**

# %%
#stemming function
# create an object of stemming function
stemmer = SnowballStemmer("english")

def stemming(text):    
    '''a function which stems each word in the given text'''
    text = [stemmer.stem(word) for word in text.split()]
    return " ".join(text)

# %%
data['permalink'] = data['permalink'].apply(stemming)
data.head(10)
# Out:
#                              permalink                    name  \
# 0                   /organization/-fam                   #fame
# 1                 /organization/-qount                :Qounter
# 2  /organization/-the-one-of-them-inc-  (THE) ONE of THEM,Inc.
# 3                /organization/0-6-com                 0-6.com
# 4          /organization/004-technolog        004 Technologies
# 5      /organization/01games-technolog      01Games Technology
# 6  /organization/0ndine-biomedical-inc  Ondine Biomedical Inc.
# 7                 /organization/0xdata                  H2O.ai
# 8                      /organization/1                One Inc.
# 9            /organization/1-2-3-listo             1,2,3 Listo
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
# 5             http://www.01games.hk/
# ...

# %% [markdown]
# # **create the object of tfid vectorizer**

# %%
# create the object of tfid vectorizer
tfid_vectorizer = TfidfVectorizer(stop_words = 'english')

# fit the vectorizer using the text data
tfid_vectorizer.fit(data['permalink'])

# collect the vocabulary items used in the vectorizer
dictionary = tfid_vectorizer.vocabulary_.items()

# %% [markdown]
# # **lists to store the vocab and counts**

# %%
# lists to store the vocab and counts
vocab = []
count = []
# iterate through each vocab and count append the value to designated lists
for key, value in dictionary:
    vocab.append(key)
    count.append(value)
# store the count in panadas dataframe with vocab as index
vocab_after_stem = pd.Series(count, index=vocab)
# sort the dataframe
vocab_after_stem = vocab_after_stem.sort_values(ascending=False)
# plot of the top vocab
top_vacab = vocab_after_stem.head(20)
top_vacab.plot(kind = 'bar', figsize=(10,5))

# %%
def length(text):    
    '''a function which returns the length of text'''
    return len(text)

# %%
data['length'] = data['permalink'].apply(length)
data.head(10)
# Out:
#                              permalink                    name  \
# 0                   /organization/-fam                   #fame
# 1                 /organization/-qount                :Qounter
# 2  /organization/-the-one-of-them-inc-  (THE) ONE of THEM,Inc.
# 3                /organization/0-6-com                 0-6.com
# 4          /organization/004-technolog        004 Technologies
# 5      /organization/01games-technolog      01Games Technology
# 6  /organization/0ndine-biomedical-inc  Ondine Biomedical Inc.
# 7                 /organization/0xdata                  H2O.ai
# 8                      /organization/1                One Inc.
# 9            /organization/1-2-3-listo             1,2,3 Listo
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
# 5             http://www.01games.hk/
# ...

# %%
operating_data = data[data['status'] == 'operating' ]
acquired_data = data[data['status'] == 'acquired']
closed_data = data[data['status'] == 'closed']
ipo_data = data[data['status'] == 'ipo']

# %%
operating_data
# Out:
#                                                permalink  \
# 0                                     /organization/-fam
# 1                                   /organization/-qount
# 2                    /organization/-the-one-of-them-inc-
# 3                                  /organization/0-6-com
# 4                            /organization/004-technolog
# ...                                                  ...
# 66363  /organization/zznode-science-and-technology-co...
# 66364                          /organization/zzzzapp-com
# 66365                                /organization/áeron
# 66366                              /organization/ôasys-2
# 66367  /organization/i̇novatiff-reklam-ve-tanıtım-hiz...
#
#                                              name  \
# 0                                           #fame
# 1                                        :Qounter
# 2                          (THE) ONE of THEM,Inc.
# 3                                         0-6.com
# ...

# %% [markdown]
# # **Count of words in operating_data**

# %%
#Count of words in operating_data
# create the object of tfid vectorizer
tfid_vectorizer = TfidfVectorizer(stop_words = 'english')

# fit the vectorizer using the text data
tfid_vectorizer.fit(operating_data['permalink'])

# collect the vocabulary items used in the vectorizer
dictionary = tfid_vectorizer.vocabulary_.items()

# %% [markdown]
# # **lists to store the vocab and counts**

# %%
# lists to store the vocab and counts
vocab = []
count = []
# iterate through each vocab and count append the value to designated lists
for key, value in dictionary:
    vocab.append(key)
    count.append(value)
# store the count in panadas dataframe with vocab as index
vocab_after_stem = pd.Series(count, index=vocab)
# sort the dataframe
vocab_after_stem = vocab_after_stem.sort_values(ascending=False)
# plot of the top vocab
top_vacab = vocab_after_stem.head(20)
top_vacab.plot(kind = 'bar', figsize=(10,5))

# %% [markdown]
# # **Count of words in acquired_data**

# %%
#Count of words in acquired_data
# create the object of tfid vectorizer
tfid_vectorizer = TfidfVectorizer(stop_words = 'english')

# fit the vectorizer using the text data
tfid_vectorizer.fit(acquired_data['permalink'])

# collect the vocabulary items used in the vectorizer
dictionary = tfid_vectorizer.vocabulary_.items()

# %% [markdown]
# # **lists to store the vocab and counts**

# %%
# lists to store the vocab and counts
vocab = []
count = []
# iterate through each vocab and count append the value to designated lists
for key, value in dictionary:
    vocab.append(key)
    count.append(value)
# store the count in panadas dataframe with vocab as index
vocab_after_stem = pd.Series(count, index=vocab)
# sort the dataframe
vocab_after_stem = vocab_after_stem.sort_values(ascending=False)
# plot of the top vocab
top_vacab = vocab_after_stem.head(20)
top_vacab.plot(kind = 'bar', figsize=(15,5))

# %% [markdown]
# # **Count of words in closed_data**

# %%
#Count of words in closed_data
# create the object of tfid vectorizer
tfid_vectorizer = TfidfVectorizer(stop_words = 'english')

# fit the vectorizer using the text data
tfid_vectorizer.fit(closed_data['permalink'])

# collect the vocabulary items used in the vectorizer
dictionary = tfid_vectorizer.vocabulary_.items()

# %% [markdown]
# # **lists to store the vocab and counts**

# %%
# lists to store the vocab and counts
vocab = []
count = []
# iterate through each vocab and count append the value to designated lists
for key, value in dictionary:
    vocab.append(key)
    count.append(value)
# store the count in panadas dataframe with vocab as index
vocab_after_stem = pd.Series(count, index=vocab)
# sort the dataframe
vocab_after_stem = vocab_after_stem.sort_values(ascending=False)
# plot of the top vocab
top_vacab = vocab_after_stem.head(20)
top_vacab.plot(kind = 'bar', figsize=(15,5))

# %% [markdown]
# # **Count of words in ipo_data**

# %%
#Count of words in ipo_data
# create the object of tfid vectorizer
tfid_vectorizer = TfidfVectorizer(stop_words = 'english')

# fit the vectorizer using the text data
tfid_vectorizer.fit(ipo_data['permalink'])

# collect the vocabulary items used in the vectorizer
dictionary = tfid_vectorizer.vocabulary_.items()

# %% [markdown]
# # **lists to store the vocab and counts**

# %%
# lists to store the vocab and counts
vocab = []
count = []
# iterate through each vocab and count append the value to designated lists
for key, value in dictionary:
    vocab.append(key)
    count.append(value)
# store the count in panadas dataframe with vocab as index
vocab_after_stem = pd.Series(count, index=vocab)
# sort the dataframe
vocab_after_stem = vocab_after_stem.sort_values(ascending=False)
# plot of the top vocab
top_vacab = vocab_after_stem.head(20)
top_vacab.plot(kind = 'bar', figsize=(15,5))

# %% [markdown]
# ## **Word cloud**

# %%
from wordcloud import WordCloud ,STOPWORDS

# %%
def create_wordcloud(words):
    wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(words)
    plt.figure(figsize=(10, 7))
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis('off')
    plt.show()

# %%
subset=data[data.status=="closed"]
text=subset.permalink.values
words =" ".join(text)
create_wordcloud(words)

# %%
subset=data[data.status=="ipo"]
text=subset.permalink.values
words =" ".join(text)
create_wordcloud(words)

# %%
subset=data[data.status=="operating"]
text=subset.permalink.values
words =" ".join(text)
create_wordcloud(words)

# %%
subset=data[data.status=="acquired"]
text=subset.permalink.values
words =" ".join(text)
create_wordcloud(words)
