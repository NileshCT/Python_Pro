# %% [markdown]
# <a href="https://colab.research.google.com/github/NileshCT/Hello-Nilesh/blob/main/EDA_using_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
path = "/content/drive/MyDrive/dataset.csv"
data= pd.read_csv(path)

#step one understanding of data

# %%
#for to check 1st five
data.head()
# Out:
#                              permalink                    name  \
# 0                  /organization/-fame                   #fame
# 1               /organization/-qounter                :Qounter
# 2  /organization/-the-one-of-them-inc-  (THE) ONE of THEM,Inc.
# 3                /organization/0-6-com                 0-6.com
# 4       /organization/004-technologies        004 Technologies
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
#
#                                        category_list funding_total_usd  \
# 0                                              Media          10000000
# 1  Application Platforms|Real Time|Social Network...            700000
# 2                                  Apps|Games|Mobile           3406878
# ...

# %%
#to check last five 
data.tail()
# Out:
#                                                permalink  \
# 66363  /organization/zznode-science-and-technology-co...
# 66364                          /organization/zzzzapp-com
# 66365                                /organization/Áeron
# 66366                              /organization/Ôasys-2
# 66367  /organization/İnovatiff-reklam-ve-tanıtım-hizm...
#
#                                              name            homepage_url  \
# 66363               ZZNode Science and Technology   http://www.zznode.com
# 66364                       Zzzzapp Wireless ltd.  http://www.zzzzapp.com
# 66365                                       ÁERON    http://www.aeron.hu/
# 66366                                       Ôasys    http://www.oasys.io/
# 66367  İnovatiff Reklam ve Tanıtım Hizmetleri Tic    http://inovatiff.com
#
#                                            category_list funding_total_usd  \
# 66363                                Enterprise Software           1587301
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66368 entries, 0 to 66367
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   permalink          66368 non-null  object
#  1   name               66367 non-null  object
#  2   homepage_url       61310 non-null  object
#  3   category_list      63220 non-null  object
#  4   funding_total_usd  66368 non-null  object
#  5   status             66368 non-null  object
#  6   country_code       59410 non-null  object
#  7   state_code         57821 non-null  object
#  8   region             58338 non-null  object
#  9   city               58340 non-null  object
#  10  funding_rounds     66368 non-null  int64
#  11  founded_at         51147 non-null  object
#  12  first_funding_at   66344 non-null  object
#  13  last_funding_at    66368 non-null  object
# dtypes: int64(1), object(13)
# memory usage: 7.1+ MB

# %%
# to check the shape of data set
data.shape
# Out:
# (66368, 14)

# %%
#to discribe the dataset
data.describe()
# Out:
#        funding_rounds
# count    66368.000000
# mean         1.732522
# std          1.360251
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max         19.000000

# %%
#to check no. of column
data.columns
# Out:
# Index(['permalink', 'name', 'homepage_url', 'category_list',
#        'funding_total_usd', 'status', 'country_code', 'state_code', 'region',
#        'city', 'funding_rounds', 'founded_at', 'first_funding_at',
#        'last_funding_at'],
#       dtype='object')

# %%
#to check the unique values in data set
data.nunique()
# Out:
# permalink            66368
# name                 66102
# homepage_url         61191
# category_list        27296
# funding_total_usd    18896
# status                   4
# country_code           137
# state_code             311
# region                1092
# city                  5111
# funding_rounds          19
# founded_at            3978
# first_funding_at      4817
# last_funding_at       4518
# dtype: int64

# %%
#to check separate unique value in column
data["category_list"].unique()
# Out:
# array(['Media', 'Application Platforms|Real Time|Social Network Media',
#        'Apps|Games|Mobile', ...,
#        'Advertising|Mobile|Web Development|Wireless',
#        'Consumer Electronics|Internet of Things|Telecommunications',
#        'Consumer Goods|E-Commerce|Internet'], dtype=object)

# %%
#step two cleaning of data
#to check null values in data
data.isnull().sum()
# Out:
# permalink                0
# name                     1
# homepage_url          5058
# category_list         3148
# funding_total_usd        0
# status                   0
# country_code          6958
# state_code            8547
# region                8030
# city                  8028
# funding_rounds           0
# founded_at           15221
# first_funding_at        24
# last_funding_at          0
# dtype: int64

# %%
data1=data.copy()

# %%
#drop unwanted data
data1.drop(["permalink","homepage_url","homepage_url","category_list","country_code","state_code","region","city","founded_at","first_funding_at"],axis=1)
# Out:
#                                              name funding_total_usd  \
# 0                                           #fame          10000000
# 1                                        :Qounter            700000
# 2                          (THE) ONE of THEM,Inc.           3406878
# 3                                         0-6.com           2000000
# 4                                004 Technologies                 -
# ...                                           ...               ...
# 66363               ZZNode Science and Technology           1587301
# 66364                       Zzzzapp Wireless ltd.            114304
# 66365                                       ÁERON                 -
# 66366                                       Ôasys             18192
# 66367  İnovatiff Reklam ve Tanıtım Hizmetleri Tic             14851
#
#           status  funding_rounds last_funding_at
# 0      operating               1      2015-01-05
# 1      operating               2      2014-10-14
# ...

# %%
#relationship analysis
#develop corelationship amanalysis
corelation=data1.corr()

# %%
#generate heat map with sns library
sns.heatmap(corelation,xticklabels=corelation.columns,yticklabels=corelation.columns,annot=True)

# %%
#plot pairplot
sns.pairplot(data1)

# %%
#to plot scatter plot
sns.scatterplot(x="funding_total_usd",y="funding_rounds",hue="name",data=data1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-0ab5bc07bb3f> in <module>
#       1 #to plot scatter plot
# ----> 2 sns.scatterplot(x="funding_total_usd",y="funding_rounds",hue="name",data=data1)
#
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.8/dist-packages/seaborn/relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     806
#     807     variables = _ScatterPlotter.get_semantics(locals())
# --> 808     p = _ScatterPlotter(
# ...

# %%
sns.distplot(data1["funding_rounds"])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#to display histogram with 5 dividon
sns.distplot(data1["funding_rounds"],bins=5)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
